# %% [markdown]
# The output is a batch of feature vectors. For each input image, the feature vector has size num_features = 2048. The feature vectors can then be used further, e.g., for classification as above.
#
# The input images are expected to have color values in the range [0,1], following the common image input conventions. The expected size of the input images is height x width = 299 x 299 pixels by default, but other input sizes are possible (within limits).

# %%
# %reset -f

# %%
dataset_path = "/Users/manojamme/Downloads/archive/seed_iv"

# %%
spectrogram_height = 229
spectrogram_width = 229
hop_size = 3

frame_size = ((spectrogram_height-1) * 2)
sample_size = ((spectrogram_width-1) * hop_size)

# %%
fs = 200

# %%
pip install tensorflow_hub
# Out:
# Requirement already satisfied: tensorflow_hub in /opt/anaconda3/lib/python3.12/site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow_hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow_hub) (3.20.3)
# Requirement already satisfied: tf-keras>=2.14.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow_hub) (2.18.0)
# Requirement already satisfied: tensorflow<2.19,>=2.18 in /opt/anaconda3/lib/python3.12/site-packages (from tf-keras>=2.14.1->tensorflow_hub) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (3.3.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (23.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2.32.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (1.65.4)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (3.6.0)
# Requirement already satisfied: h5py>=3.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (0.43.0)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras>=2.14.1->tensorflow_hub) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (0.59.1)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.12.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: pooch>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (1.8.2)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.5.0.post1-cp312-abi3-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from lazy-loader>=0.1->librosa) (23.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/anaconda3/lib/python3.12/site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from pooch>=1.1->librosa) (2.32.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.7.4)
# Downloading librosa-0.10.2.post1-py3-none-any.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.1/260.1 kB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading soundfile-0.12.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.6 MB/s eta 0:00:0000:0100:01m
# Downloading soxr-0.5.0.post1-cp312-abi3-macosx_11_0_arm64.whl (156 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.4/156.4 kB 15.4 MB/s eta 0:00:00
# Installing collected packages: soxr, audioread, soundfile, librosa
# Successfully installed audioread-3.0.1 librosa-0.10.2.post1 soundfile-0.12.1 soxr-0.5.0.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import math
import numpy as np
# import pandas as pd
import scipy.io as sio
from sklearn import preprocessing
from scipy.signal import butter, lfilter
from scipy.io import loadmat

# %%
import os
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow_hub as hub

# %%
import gc

# %%
import time

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
def compute_spectrogram(signal, sr=fs,frame_size = frame_size, hop = hop_size):
    stft = librosa.stft(signal, n_fft=frame_size, hop_length=hop)
    log_stft= librosa.power_to_db(np.abs(stft) ** 2)
    return log_stft
#     print(log_stft.shape)
#     plot_spectrogram(log_stft, sr, hop, y_axis="log")

# %%
def plot_spectrogram(Y, sr=fs, hop_length=hop_size, y_axis="linear"):
    plt.figure(figsize=(25, 10))
    librosa.display.specshow(Y, 
                             sr=sr, 
                             hop_length=hop_length, 
                             x_axis="time", 
                             y_axis=y_axis)
    plt.colorbar(format="%+2.f")

# %%
session1_label = [1,2,3,0,2,0,0,1,0,1,2,1,1,1,2,3,2,2,3,3,0,3,0,3]
session2_label = [2,1,3,0,0,2,0,2,3,3,2,3,2,0,1,1,2,1,0,3,0,1,3,1]
session3_label = [1,2,2,1,3,3,3,1,1,2,1,0,2,3,3,0,2,3,0,0,2,0,1,0]

# %%
session_label_dict = {}
session_label_dict[1] = session1_label
session_label_dict[2] = session2_label
session_label_dict[3] = session3_label
session_label_dict
# Out:
# {1: [1, 2, 3, 0, 2, 0, 0, 1, 0, 1, 2, 1, 1, 1, 2, 3, 2, 2, 3, 3, 0, 3, 0, 3],
#  2: [2, 1, 3, 0, 0, 2, 0, 2, 3, 3, 2, 3, 2, 0, 1, 1, 2, 1, 0, 3, 0, 1, 3, 1],
#  3: [1, 2, 2, 1, 3, 3, 3, 1, 1, 2, 1, 0, 2, 3, 3, 0, 2, 3, 0, 0, 2, 0, 1, 0]}

# %%
all_trial_sizes = {}
for exp in range(1,4):
    all_trial_sizes[exp] = []

# %%
fs = 200

def decompose_ram_efficient(file, file_mat, exp_id):
    t_start = time.time()
    # trial*channel*sample
    feature_extractor_model = "https://tfhub.dev/google/imagenet/inception_v3/feature_vector/5"
    out_dim_of_TL_model = 2048
    data = loadmat(file)
    frequency = fs
#     time_window = 0.5
#     data_points_per_sample = frequency * time_window  #fz = 200per sec -> 100 data_points per 0.5sec window
    data_points_per_sample = sample_size
    name = ""
    for char in list(data.keys())[7]: #instead of 7, u can pass any no. between 3 and 15
      if char == "_":
        break
      name = name+char

#     fft_crop_length = 21 

    decomposed_specgram = np.empty([0, 62, 229, 229, 3])
    label = np.array([])


    x_TL_features = np.empty([0, 62, out_dim_of_TL_model])
    
    
    for trial in range(24):
        tmp_trial_signal = data[name + '_eeg' + str(trial + 1)]
        num_sample = int(len(tmp_trial_signal[0]) / data_points_per_sample) 
        print('{}-{}'.format(trial + 1, num_sample))
        all_trial_sizes[exp_id].append(num_sample)

        # temp_fft = np.empty([0, num_sample, 21])
        temp_specgram = np.empty([0, 229, 229])
        label = np.append(label, [session_label_dict[exp_id][trial]] * num_sample)

        t1_spec  =time.time()
        for channel in range(62):
            trial_signal = tmp_trial_signal[channel]

            delta_theta_alpha = butter_bandpass_filter(trial_signal, 1, 14, frequency, order=3)
            delta_theta_alpha = delta_theta_alpha+abs(np.min(delta_theta_alpha))
            delta_theta_alpha = delta_theta_alpha/np.max(delta_theta_alpha)
            
            beta = butter_bandpass_filter(trial_signal, 14, 31, frequency, order=3)
            beta = beta+abs(np.min(beta))
            beta = beta/np.max(beta)
            
            gamma = butter_bandpass_filter(trial_signal, 31, 51, frequency, order=3)
            gamma = gamma+abs(np.min(gamma))
            gamma = gamma/np.max(gamma)

            specgram_delta_theta_alpha = np.zeros(shape=[0, 229, 229], dtype=float)
            specgram_beta = np.zeros(shape=[0, 229, 229], dtype=float)
            specgram_gamma = np.zeros(shape=[0, 229, 229], dtype=float)

            for index in range(num_sample):
                specgram_delta_theta_alpha = np.vstack([specgram_delta_theta_alpha, compute_spectrogram(delta_theta_alpha[index * sample_size:(index + 1) * sample_size]).reshape(1,229,229)])
                specgram_beta = np.vstack([specgram_beta, compute_spectrogram(beta[index * sample_size:(index + 1) * sample_size]).reshape(1,229,229)])
                specgram_gamma = np.vstack([specgram_gamma, compute_spectrogram(gamma[index * sample_size:(index + 1) * sample_size]).reshape(1,229,229)])
                # print(fft_delta.shape, fft_theta.shape, fft_alpha.shape, fft_beta.shape, fft_gamma.shape)

            temp_specgram = np.vstack([temp_specgram, specgram_delta_theta_alpha])
            temp_specgram = np.vstack([temp_specgram, specgram_beta])
            temp_specgram = np.vstack([temp_specgram, specgram_gamma])

        t2_spec = time.time()
        temp_trial_specgram = temp_specgram.reshape(-1, 3, num_sample, 229, 229)
        temp_trial_specgram = temp_trial_specgram.transpose([2, 0, 3, 4, 1])
        subject_id = ""
        for i in file_mat:
            if i == "_":
                break
            subject_id += i
#         np.save(f"{dataset_path}/my_extracted_features/spectrogram(229_229_3)/{subject_id}_{trial+1}_X_1D.npy",temp_trial_specgram)
#         decomposed_specgram = np.vstack([decomposed_specgram, temp_trial_specgram])
#         

        subject = subject_id
#         trial_group = en+1


        temp_x = temp_trial_specgram #(#,62,229,229,3)
        print(f"time for subject:{subject}, exp:{exp_id} and trial:{trial+1} for specgrams is: {t2_spec - t1_spec}")
        print(f"subject:{subject}, exp:{exp_id} and trial:{trial+1} has specgrams as: {temp_x.shape}")
        
        # spectrogram creation complete
        
############################# TL start ##################################    
        # starting Transefer learning, forward pass in inception v3 with top layer removed
        t1_TL = time.time()
        pretrained_model_without_top_layer = hub.KerasLayer(
            feature_extractor_model, input_shape=(229, 229, 3), trainable=False)

        
        for sample in range(temp_x.shape[0]):
            temp_x_TL_features = np.empty([0, out_dim_of_TL_model])
            for channel in range(temp_x.shape[1]):
                results = ((np.array(pretrained_model_without_top_layer(temp_x[sample,channel].reshape((1,229,229,3))))))
                temp_x_TL_features = np.vstack([temp_x_TL_features, results])
            temp_x_TL_features = temp_x_TL_features.reshape((1,temp_x_TL_features.shape[0],out_dim_of_TL_model))
            x_TL_features = np.vstack([x_TL_features, temp_x_TL_features])
        
        t2_TL = time.time()
        print(f"time for subject:{subject}, exp:{exp_id} and trial:{trial+1} for TL is: {t2_TL - t1_TL}")
        temp_x = None 
        temp_trial_specgram = None
        gc.collect()
############################# TL done ##################################        
    
####converting EEG signals to 8x9 feature map, to capture their spatial information and pass to CNN model later ####
####for more information about 8x9 map, refer to paper with following link or DOI ####
# link: https://www.itm-conferences.org/articles/itmconf/abs/2023/03/itmconf_icdsia2023_02011/itmconf_icdsia2023_02011.html
# DOI: https://doi.org/10.1051/itmconf/20235302011        
    print(f"TL_features_for subject:{subject} and exp:{exp_id} -> {x_TL_features.shape}")

    t1_x89 = time.time()
    X89 = np.zeros((x_TL_features.shape[0], 8, 9, out_dim_of_TL_model))
    
    X89[:, 0, 2, :] = x_TL_features[:, 3, :]
    X89[:, 0, 3:6, :] = x_TL_features[:, 0:3, :]
    X89[:, 0, 6, :] = x_TL_features[:, 4, :]

    for i in range(5):
      X89[:, i + 1, :, :] = x_TL_features[:, 5 + i * 9:5 + (i + 1) * 9, :]

    X89[:, 6, 1:8, :] = x_TL_features[:, 50:57, :]
    X89[:, 7, 2:7, :] = x_TL_features[:, 57:62, :]
    
    t2_x89 = time.time()
    print(f"time for 8*9 map for subject:{subject} and exp:{exp_id} is -> {t2_x89 - t1_x89}")
    print(f"8*9 map dim for subject:{subject} and exp:{exp_id} is -> {X89.shape}")


    np.save(f"{dataset_path}/my_extracted_features/spectrogram(224_224_3)/TL_inception_v3/{subject}_{exp_id}_X89.npy",X89)
    np.save(f"{dataset_path}/my_extracted_features/spectrogram(224_224_3)/TL_inception_v3/{subject}_{exp_id}_y.npy",label)

    t_end = time.time()
    print(f"time for subject:{subject} and exp:{exp_id} is -> {t_end - t_start} sec.")
#     x89 = np.load(f"{dataset_path}/my_extracted_features/spectrogram(224_224_3)/TL_mobilenet_v2/{subject}_{trial_group}_X89.npy")
#     print(x89.shape)
    print("######################################################")


#         %reset -f

# %%
eeg_raw_file_path = f"{dataset_path}/eeg_raw_data/"

# %%
session_file_dict = {}
for exp in range(1,4):
    files = os.listdir(f"{eeg_raw_file_path}{str(exp)}")
    files.sort(key= (lambda i : i[:2] if i[1]!="_" else "0"+i[0]) )
    session_file_dict[exp] = files

# %%
session_file_dict
# Out:
# {}

# %% [markdown]
# for subject in range(13,14):
#     for exp in range(2,4):
#         file_name = f"{eeg_raw_file_path}{str(exp)}/{session_file_dict[exp][subject]}"
#         print(f'processing {session_file_dict[exp][subject]}')
#         decompose_ram_efficient(file_name, session_file_dict[exp][subject], exp)
#     for exp in range(1,4):
#         all_trial_sizes[exp] = []
#     print("###########################################################")

# %%
for subject in range(0,1):
    for exp in range(1,4):
        file_name = f"{eeg_raw_file_path}{str(exp)}/{session_file_dict[exp][subject]}"
        print(f'processing {session_file_dict[exp][subject]}')
        decompose_ram_efficient(file_name, session_file_dict[exp][subject], exp)
    for exp in range(1,4):
        all_trial_sizes[exp] = []
    print("###########################################################")
# Out:
# processing 1_20160518.mat
# 1-49
# time for subject:1, exp:1 and trial:1 for specgrams is: 677.6738729476929
# subject:1, exp:1 and trial:1 has specgrams as: (49, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:1 for TL is: 160.38778114318848
# 2-27
# time for subject:1, exp:1 and trial:2 for specgrams is: 45.024385929107666
# subject:1, exp:1 and trial:2 has specgrams as: (27, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:2 for TL is: 69.56646823883057
# 3-58
# time for subject:1, exp:1 and trial:3 for specgrams is: 1038.276782989502
# subject:1, exp:1 and trial:3 has specgrams as: (58, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:3 for TL is: 152.05930018424988
# 4-38
# time for subject:1, exp:1 and trial:4 for specgrams is: 114.41753315925598
# subject:1, exp:1 and trial:4 has specgrams as: (38, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:4 for TL is: 98.93956899642944
# 5-25
# time for subject:1, exp:1 and trial:5 for specgrams is: 40.555118799209595
# subject:1, exp:1 and trial:5 has specgrams as: (25, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:5 for TL is: 64.97318410873413
# 6-47
# time for subject:1, exp:1 and trial:6 for specgrams is: 448.90932416915894
# subject:1, exp:1 and trial:6 has specgrams as: (47, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:6 for TL is: 121.71503210067749
# 7-44
# time for subject:1, exp:1 and trial:7 for specgrams is: 275.7632191181183
# subject:1, exp:1 and trial:7 has specgrams as: (44, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:7 for TL is: 109.21878409385681
# 8-61
# time for subject:1, exp:1 and trial:8 for specgrams is: 1201.419781923294
# subject:1, exp:1 and trial:8 has specgrams as: (61, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:8 for TL is: 155.09425687789917
# 9-42
# time for subject:1, exp:1 and trial:9 for specgrams is: 230.43967390060425
# subject:1, exp:1 and trial:9 has specgrams as: (42, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:9 for TL is: 103.09068703651428
# 10-49
# time for subject:1, exp:1 and trial:10 for specgrams is: 519.1749680042267
# subject:1, exp:1 and trial:10 has specgrams as: (49, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:10 for TL is: 125.52056694030762
# 11-14
# time for subject:1, exp:1 and trial:11 for specgrams is: 16.328535079956055
# subject:1, exp:1 and trial:11 has specgrams as: (14, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:11 for TL is: 35.89692997932434
# 12-32
# time for subject:1, exp:1 and trial:12 for specgrams is: 95.5435950756073
# subject:1, exp:1 and trial:12 has specgrams as: (32, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:12 for TL is: 81.99929809570312
# 13-63
# time for subject:1, exp:1 and trial:13 for specgrams is: 1345.144227027893
# subject:1, exp:1 and trial:13 has specgrams as: (63, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:13 for TL is: 168.512371301651
# 14-49
# time for subject:1, exp:1 and trial:14 for specgrams is: 452.49384593963623
# subject:1, exp:1 and trial:14 has specgrams as: (49, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:14 for TL is: 129.33211517333984
# 15-75
# time for subject:1, exp:1 and trial:15 for specgrams is: 1959.5354890823364
# subject:1, exp:1 and trial:15 has specgrams as: (75, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:15 for TL is: 207.22615003585815
# 16-41
# time for subject:1, exp:1 and trial:16 for specgrams is: 164.53159093856812
# subject:1, exp:1 and trial:16 has specgrams as: (41, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:16 for TL is: 111.83752036094666
# 17-19
# time for subject:1, exp:1 and trial:17 for specgrams is: 27.830443143844604
# subject:1, exp:1 and trial:17 has specgrams as: (19, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:17 for TL is: 50.97874593734741
# 18-52
# time for subject:1, exp:1 and trial:18 for specgrams is: 704.8190860748291
# subject:1, exp:1 and trial:18 has specgrams as: (52, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:18 for TL is: 148.12489104270935
# 19-40
# time for subject:1, exp:1 and trial:19 for specgrams is: 161.62745308876038
# subject:1, exp:1 and trial:19 has specgrams as: (40, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:19 for TL is: 111.42052721977234
# 20-14
# time for subject:1, exp:1 and trial:20 for specgrams is: 17.47173285484314
# subject:1, exp:1 and trial:20 has specgrams as: (14, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:20 for TL is: 37.82007694244385
# 21-32
# time for subject:1, exp:1 and trial:21 for specgrams is: 93.10242509841919
# subject:1, exp:1 and trial:21 has specgrams as: (32, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:21 for TL is: 89.55488109588623
# 22-32
# time for subject:1, exp:1 and trial:22 for specgrams is: 89.00492691993713
# subject:1, exp:1 and trial:22 has specgrams as: (32, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:22 for TL is: 90.08776307106018
# 23-51
# time for subject:1, exp:1 and trial:23 for specgrams is: 597.4341790676117
# subject:1, exp:1 and trial:23 has specgrams as: (51, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:23 for TL is: 152.8156280517578
# 24-40
# time for subject:1, exp:1 and trial:24 for specgrams is: 126.86258792877197
# subject:1, exp:1 and trial:24 has specgrams as: (40, 62, 229, 229, 3)
# time for subject:1, exp:1 and trial:24 for TL is: 110.89740204811096
# TL_features_for subject:1 and exp:1 -> (994, 62, 2048)
# time for 8*9 map for subject:1 and exp:1 is -> 0.49883198738098145
# 8*9 map dim for subject:1 and exp:1 is -> (994, 8, 9, 2048)
# time for subject:1 and exp:1 is -> 13154.269716024399 sec.
# ######################################################
# processing 1_20161125.mat
# 1-64
# time for subject:1, exp:2 and trial:1 for specgrams is: 1361.4333777427673
# subject:1, exp:2 and trial:1 has specgrams as: (64, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:1 for TL is: 159.8815598487854
# 2-29
# time for subject:1, exp:2 and trial:2 for specgrams is: 53.0198860168457
# subject:1, exp:2 and trial:2 has specgrams as: (29, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:2 for TL is: 70.7202742099762
# 3-40
# time for subject:1, exp:2 and trial:3 for specgrams is: 159.24525690078735
# subject:1, exp:2 and trial:3 has specgrams as: (40, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:3 for TL is: 98.21505784988403
# 4-42
# time for subject:1, exp:2 and trial:4 for specgrams is: 252.81803131103516
# subject:1, exp:2 and trial:4 has specgrams as: (42, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:4 for TL is: 104.80889296531677
# 5-62
# time for subject:1, exp:2 and trial:5 for specgrams is: 1298.0029273033142
# subject:1, exp:2 and trial:5 has specgrams as: (62, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:5 for TL is: 171.10582971572876
# 6-32
# time for subject:1, exp:2 and trial:6 for specgrams is: 86.70365715026855
# subject:1, exp:2 and trial:6 has specgrams as: (32, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:6 for TL is: 83.46428680419922
# 7-40
# time for subject:1, exp:2 and trial:7 for specgrams is: 218.55740189552307
# subject:1, exp:2 and trial:7 has specgrams as: (40, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:7 for TL is: 110.1664879322052
# 8-53
# time for subject:1, exp:2 and trial:8 for specgrams is: 809.2051160335541
# subject:1, exp:2 and trial:8 has specgrams as: (53, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:8 for TL is: 148.54159593582153
# 9-40
# time for subject:1, exp:2 and trial:9 for specgrams is: 186.31963801383972
# subject:1, exp:2 and trial:9 has specgrams as: (40, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:9 for TL is: 106.44799494743347
# 10-24
# time for subject:1, exp:2 and trial:10 for specgrams is: 39.94860792160034
# subject:1, exp:2 and trial:10 has specgrams as: (24, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:10 for TL is: 63.41927981376648
# 11-70
# time for subject:1, exp:2 and trial:11 for specgrams is: 1724.6993489265442
# subject:1, exp:2 and trial:11 has specgrams as: (70, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:11 for TL is: 193.3388831615448
# 12-14
# time for subject:1, exp:2 and trial:12 for specgrams is: 16.71983575820923
# subject:1, exp:2 and trial:12 has specgrams as: (14, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:12 for TL is: 39.16989588737488
# 13-42
# time for subject:1, exp:2 and trial:13 for specgrams is: 248.85728001594543
# subject:1, exp:2 and trial:13 has specgrams as: (42, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:13 for TL is: 114.79647397994995
# 14-31
# time for subject:1, exp:2 and trial:14 for specgrams is: 77.06646394729614
# subject:1, exp:2 and trial:14 has specgrams as: (31, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:14 for TL is: 90.3323929309845
# 15-51
# time for subject:1, exp:2 and trial:15 for specgrams is: 763.274799823761
# subject:1, exp:2 and trial:15 has specgrams as: (51, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:15 for TL is: 141.08284616470337
# 16-17
# time for subject:1, exp:2 and trial:16 for specgrams is: 20.340945959091187
# subject:1, exp:2 and trial:16 has specgrams as: (17, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:16 for TL is: 48.18892812728882
# 17-54
# time for subject:1, exp:2 and trial:17 for specgrams is: 866.2344720363617
# subject:1, exp:2 and trial:17 has specgrams as: (54, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:17 for TL is: 153.83182001113892
# 18-57
# time for subject:1, exp:2 and trial:18 for specgrams is: 949.2090911865234
# subject:1, exp:2 and trial:18 has specgrams as: (57, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:18 for TL is: 164.80732798576355
# 19-53
# time for subject:1, exp:2 and trial:19 for specgrams is: 810.1011006832123
# subject:1, exp:2 and trial:19 has specgrams as: (53, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:19 for TL is: 155.73252296447754
# 20-12
# time for subject:1, exp:2 and trial:20 for specgrams is: 14.877272129058838
# subject:1, exp:2 and trial:20 has specgrams as: (12, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:20 for TL is: 31.656817197799683
# 21-43
# time for subject:1, exp:2 and trial:21 for specgrams is: 382.1768078804016
# subject:1, exp:2 and trial:21 has specgrams as: (43, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:21 for TL is: 127.33730506896973
# 22-51
# time for subject:1, exp:2 and trial:22 for specgrams is: 713.3868350982666
# subject:1, exp:2 and trial:22 has specgrams as: (51, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:22 for TL is: 149.3845489025116
# 23-28
# time for subject:1, exp:2 and trial:23 for specgrams is: 70.50958204269409
# subject:1, exp:2 and trial:23 has specgrams as: (28, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:23 for TL is: 75.40782594680786
# 24-22
# time for subject:1, exp:2 and trial:24 for specgrams is: 43.44876742362976
# subject:1, exp:2 and trial:24 has specgrams as: (22, 62, 229, 229, 3)
# time for subject:1, exp:2 and trial:24 for TL is: 64.59964513778687
# TL_features_for subject:1 and exp:2 -> (971, 62, 2048)
# time for 8*9 map for subject:1 and exp:2 is -> 0.45466113090515137
# 8*9 map dim for subject:1 and exp:2 is -> (971, 8, 9, 2048)
# time for subject:1 and exp:2 is -> 13855.86038684845 sec.
# ######################################################
# processing 1_20161126.mat
# 1-49
# time for subject:1, exp:3 and trial:1 for specgrams is: 649.8929178714752
# subject:1, exp:3 and trial:1 has specgrams as: (49, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:1 for TL is: 134.5942771434784
# 2-38
# time for subject:1, exp:3 and trial:2 for specgrams is: 220.31137681007385
# subject:1, exp:3 and trial:2 has specgrams as: (38, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:2 for TL is: 104.35861778259277
# 3-26
# time for subject:1, exp:3 and trial:3 for specgrams is: 56.88956117630005
# subject:1, exp:3 and trial:3 has specgrams as: (26, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:3 for TL is: 65.35522079467773
# 4-53
# time for subject:1, exp:3 and trial:4 for specgrams is: 922.2376549243927
# subject:1, exp:3 and trial:4 has specgrams as: (53, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:4 for TL is: 140.59096884727478
# 5-56
# time for subject:1, exp:3 and trial:5 for specgrams is: 1063.7656812667847
# subject:1, exp:3 and trial:5 has specgrams as: (56, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:5 for TL is: 149.17606496810913
# 6-30
# time for subject:1, exp:3 and trial:6 for specgrams is: 79.50473976135254
# subject:1, exp:3 and trial:6 has specgrams as: (30, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:6 for TL is: 78.98216605186462
# 7-75
# time for subject:1, exp:3 and trial:7 for specgrams is: 4133.628446817398
# subject:1, exp:3 and trial:7 has specgrams as: (75, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:7 for TL is: 1098.41951918602
# 8-27
# time for subject:1, exp:3 and trial:8 for specgrams is: 53.88411331176758
# subject:1, exp:3 and trial:8 has specgrams as: (27, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:8 for TL is: 1860.3177926540375
# 9-30
# time for subject:1, exp:3 and trial:9 for specgrams is: 79.4242889881134
# subject:1, exp:3 and trial:9 has specgrams as: (30, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:9 for TL is: 70.33408999443054
# 10-18
# time for subject:1, exp:3 and trial:10 for specgrams is: 24.472734928131104
# subject:1, exp:3 and trial:10 has specgrams as: (18, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:10 for TL is: 938.4915449619293
# 11-60
# time for subject:1, exp:3 and trial:11 for specgrams is: 1629.637573003769
# subject:1, exp:3 and trial:11 has specgrams as: (60, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:11 for TL is: 165.91398811340332
# 12-48
# time for subject:1, exp:3 and trial:12 for specgrams is: 493.32430386543274
# subject:1, exp:3 and trial:12 has specgrams as: (48, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:12 for TL is: 136.00496315956116
# 13-45
# time for subject:1, exp:3 and trial:13 for specgrams is: 389.3630590438843
# subject:1, exp:3 and trial:13 has specgrams as: (45, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:13 for TL is: 122.84075498580933
# 14-22
# time for subject:1, exp:3 and trial:14 for specgrams is: 38.6177031993866
# subject:1, exp:3 and trial:14 has specgrams as: (22, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:14 for TL is: 55.357407093048096
# 15-33
# time for subject:1, exp:3 and trial:15 for specgrams is: 107.1984691619873
# subject:1, exp:3 and trial:15 has specgrams as: (33, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:15 for TL is: 90.03193378448486
# 16-51
# time for subject:1, exp:3 and trial:16 for specgrams is: 715.7556853294373
# subject:1, exp:3 and trial:16 has specgrams as: (51, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:16 for TL is: 150.30241513252258
# 17-16
# time for subject:1, exp:3 and trial:17 for specgrams is: 20.321819305419922
# subject:1, exp:3 and trial:17 has specgrams as: (16, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:17 for TL is: 42.71979022026062
# 18-20
# time for subject:1, exp:3 and trial:18 for specgrams is: 41.62765693664551
# subject:1, exp:3 and trial:18 has specgrams as: (20, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:18 for TL is: 53.87859487533569
# 19-53
# time for subject:1, exp:3 and trial:19 for specgrams is: 582.9053871631622
# subject:1, exp:3 and trial:19 has specgrams as: (53, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:19 for TL is: 150.90000891685486
# 20-26
# time for subject:1, exp:3 and trial:20 for specgrams is: 60.39052891731262
# subject:1, exp:3 and trial:20 has specgrams as: (26, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:20 for TL is: 70.56993007659912
# 21-46
# time for subject:1, exp:3 and trial:21 for specgrams is: 634.908252954483
# subject:1, exp:3 and trial:21 has specgrams as: (46, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:21 for TL is: 137.81943321228027
# 22-45
# time for subject:1, exp:3 and trial:22 for specgrams is: 466.1413230895996
# subject:1, exp:3 and trial:22 has specgrams as: (45, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:22 for TL is: 133.32125186920166
# 23-48
# time for subject:1, exp:3 and trial:23 for specgrams is: 560.1482789516449
# subject:1, exp:3 and trial:23 has specgrams as: (48, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:23 for TL is: 140.13475131988525
# 24-45
# time for subject:1, exp:3 and trial:24 for specgrams is: 420.753381729126
# subject:1, exp:3 and trial:24 has specgrams as: (45, 62, 229, 229, 3)
# time for subject:1, exp:3 and trial:24 for TL is: 131.93585777282715
# TL_features_for subject:1 and exp:3 -> (960, 62, 2048)
# time for 8*9 map for subject:1 and exp:3 is -> 0.5850491523742676
# 8*9 map dim for subject:1 and exp:3 is -> (960, 8, 9, 2048)
# time for subject:1 and exp:3 is -> 19692.46133184433 sec.
# ######################################################
# ###########################################################

# %%
trail_samples = {1:68,2:68,3:60,4:69,5:54,6:57,7:69,8:63,9:77,10:69,11:68,12:68,13:68,14:69,15:60}

# %%
# %reset
# Out:
# Nothing done.
